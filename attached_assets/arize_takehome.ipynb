# %% [markdown]
# # Wikipedia Roman Empire with LangChain

# %%
from getpass import getpass
import os

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")

# %%
from openai import OpenAI

client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))

def call_openai(prompt):
    response = client.completions.create(
            model="gpt-3.5-turbo-instruct",
            prompt=prompt,
            temperature=0,
            max_tokens=128,
            frequency_penalty=0,
            presence_penalty=0,
    )

    return response.choices[0].text

# %% [markdown]
# # Phoenix

# %%
import phoenix as px
session = px.launch_app()
# Out:
# INFO:phoenix.config:📋 Ensuring phoenix working directory: /Users/jaychung/.phoenix
# 🌍 To view the Phoenix app in your browser, visit http://localhost:6006/
# 📖 For more information on how to use Phoenix, check out https://docs.arize.com/phoenix

# %%
px.active_session().view()
# Out:
# 📺 Opening a view to the Phoenix app. The app is running at http://localhost:6006/
#         <iframe
#             width="100%"
#             height="1000"
#             src="http://localhost:6006/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from phoenix.trace.langchain import LangChainInstrumentor

# Initialize your LangChain application
# This might vary on your use-case. An example Chain is shown below
import bs4
from langchain_chroma import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import ChatOpenAI
from langchain_community.retrievers import WikipediaRetriever

# Initialize Langchain auto-instrumentation
LangChainInstrumentor().instrument()

retriever = WikipediaRetriever()

# Set context corpus and vector store
docs = retriever.invoke("Roman Empire")
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
splits = text_splitter.split_documents(docs)
vectorstore = Chroma.from_documents(documents=splits, embedding=OpenAIEmbeddings())
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1737916754.329680 2735026 fork_posix.cc:77] Other threads are currently calling into gRPC, skipping fork() handlers
# I0000 00:00:1737916757.941713 2734713 fork_posix.cc:77] Other threads are currently calling into gRPC, skipping fork() handlers

# %%
llm = ChatOpenAI(model="gpt-3.5-turbo-0125")

# Retrieve and generate using the relevant snippets of the blog.
retriever = vectorstore.as_retriever()
from langchain import hub
from langchain.prompts import ChatPromptTemplate, HumanMessagePromptTemplate, PromptTemplate

prompt = hub.pull("rlm/rag-prompt")

prompt_v1 = ChatPromptTemplate(
    input_variables=['context', 'question'],
    metadata={
        'lc_hub_owner': 'rlm',
        'lc_hub_repo': 'rag-prompt',
        'lc_hub_commit_hash': '50442af133e61576e74536c6556cefe1fac147cad032f4377b60c436e6cdcb6e'
    },
    messages=[
        HumanMessagePromptTemplate(
            prompt=PromptTemplate(
                input_variables=['context', 'question'],
                template="""
                You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. 
                Do not source information from other than the document excerpts provided. If you don't know the answer simply return nothing.
                Question: {question} 
                Context: {context} 
                Answer:"""
            )
        )
    ]
)

def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)


rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt_v1
    | llm
    | StrOutputParser()
)

trivia_questions = [
    "Who was the second to last emperor of the roman empire?",
    "What year is traditionally considered the founding of Rome?",
    "Who was the first emperor of Rome?",
    "What was the Roman name for the Mediterranean Sea?",
    "Which Roman general famously crossed the Rubicon River in 49 BC?",
    "What structure was used by Romans for gladiatorial contests and public spectacles?",
    "What was the Roman legal code called that influenced many modern legal systems?",
    "Which Roman emperor initiated the persecution of Christians in the early 4th century AD?",
    "In Roman mythology, who was the god of war?",
    "What was the primary language spoken in ancient Rome?",
    "What was the name of the Roman Senate's advisory council of aristocratic families?",
    "Which Roman Emperor is known for dividing the Empire into the Eastern and Western Roman Empires?",
    "What was the Roman term for a large estate or farm?",
    "Which Roman structure, completed in 80 AD, could hold up to 50,000 spectators?",
    "What was the primary purpose of the Roman aqueducts?",
    "Who was the Roman poet known for writing the epic poem 'The Aeneid'?",
    "Which Roman emperor is famous for building a massive wall across northern Britain?",
    "What was the Roman currency called?",
    "What type of Roman building was used for public bathing?",
    "Who was the Roman goddess of wisdom and warfare?",
    "Which Roman general was known for his conquest of Gaul?"
]

for i in range(len(trivia_questions)):
    response = rag_chain.invoke(trivia_questions[i])

# %%
spans_df = px.Client().get_spans_dataframe()
spans_df
# Out:
# /opt/homebrew/lib/python3.11/site-packages/phoenix/trace/dsl/query.py:746: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df_attributes = pd.DataFrame.from_records(
#                                                 name  span_kind  \
# context.span_id
# aa4ba5aef445785c                  WikipediaRetriever  RETRIEVER
# ba042a8a8a032d49                 RunnablePassthrough      CHAIN
# 525e9ad3502c1d3f                VectorStoreRetriever  RETRIEVER
# 77528b7ecec4201f                         format_docs      CHAIN
# 49c542514bec8b37                    RunnableSequence      CHAIN
# ...                                              ...        ...
# 25157c04571db771  RunnableParallel<context,question>      CHAIN
# 1b24320f18b047ef                  ChatPromptTemplate    UNKNOWN
# 63bb4656c3e24cdc                          ChatOpenAI        LLM
# edaee3b7d922236f                     StrOutputParser    UNKNOWN
# 3a62362d3dd5dce9                    RunnableSequence      CHAIN
#
#                          parent_id                       start_time  \
# context.span_id
# aa4ba5aef445785c              None 2025-01-26 18:39:13.626509+00:00
# ba042a8a8a032d49  2458807d696bdf48 2025-01-26 18:39:20.444350+00:00
# 525e9ad3502c1d3f  49c542514bec8b37 2025-01-26 18:39:20.445166+00:00
# 77528b7ecec4201f  49c542514bec8b37 2025-01-26 18:39:20.982938+00:00
# 49c542514bec8b37  2458807d696bdf48 2025-01-26 18:39:20.444918+00:00
# ...                            ...                              ...
# 25157c04571db771  3a62362d3dd5dce9 2025-01-26 18:39:39.795907+00:00
# 1b24320f18b047ef  3a62362d3dd5dce9 2025-01-26 18:39:40.258154+00:00
# 63bb4656c3e24cdc  3a62362d3dd5dce9 2025-01-26 18:39:40.260718+00:00
# edaee3b7d922236f  3a62362d3dd5dce9 2025-01-26 18:39:40.586986+00:00
# 3a62362d3dd5dce9              None 2025-01-26 18:39:39.795688+00:00
#
#                                          end_time status_code status_message  \
# context.span_id
# aa4ba5aef445785c 2025-01-26 18:39:16.612048+00:00          OK
# ba042a8a8a032d49 2025-01-26 18:39:20.444620+00:00          OK
# 525e9ad3502c1d3f 2025-01-26 18:39:20.977114+00:00          OK
# 77528b7ecec4201f 2025-01-26 18:39:20.984094+00:00          OK
# 49c542514bec8b37 2025-01-26 18:39:20.987749+00:00          OK
# ...                                           ...         ...            ...
# 25157c04571db771 2025-01-26 18:39:40.255990+00:00          OK
# 1b24320f18b047ef 2025-01-26 18:39:40.258691+00:00          OK
# 63bb4656c3e24cdc 2025-01-26 18:39:40.584411+00:00          OK
# edaee3b7d922236f 2025-01-26 18:39:40.587325+00:00          OK
# 3a62362d3dd5dce9 2025-01-26 18:39:40.588878+00:00          OK
#
#                  events   context.span_id                  context.trace_id  \
# context.span_id
# aa4ba5aef445785c     []  aa4ba5aef445785c  40c7ea7560fe000612dbf5375abd2894
# ba042a8a8a032d49     []  ba042a8a8a032d49  34b7e4f25fe292d7c0c4948a7c8be4b2
# 525e9ad3502c1d3f     []  525e9ad3502c1d3f  34b7e4f25fe292d7c0c4948a7c8be4b2
# 77528b7ecec4201f     []  77528b7ecec4201f  34b7e4f25fe292d7c0c4948a7c8be4b2
# 49c542514bec8b37     []  49c542514bec8b37  34b7e4f25fe292d7c0c4948a7c8be4b2
# ...                 ...               ...                               ...
# 25157c04571db771     []  25157c04571db771  21c33629aec650c5d92f19ffc2007f2c
# 1b24320f18b047ef     []  1b24320f18b047ef  21c33629aec650c5d92f19ffc2007f2c
# 63bb4656c3e24cdc     []  63bb4656c3e24cdc  21c33629aec650c5d92f19ffc2007f2c
# edaee3b7d922236f     []  edaee3b7d922236f  21c33629aec650c5d92f19ffc2007f2c
# 3a62362d3dd5dce9     []  3a62362d3dd5dce9  21c33629aec650c5d92f19ffc2007f2c
#
#                   ... attributes.input.mime_type  \
# context.span_id   ...
# aa4ba5aef445785c  ...                       None
# ba042a8a8a032d49  ...                       None
# 525e9ad3502c1d3f  ...                       None
# 77528b7ecec4201f  ...           application/json
# 49c542514bec8b37  ...                       None
# ...               ...                        ...
# 25157c04571db771  ...                       None
# 1b24320f18b047ef  ...           application/json
# 63bb4656c3e24cdc  ...           application/json
# edaee3b7d922236f  ...           application/json
# 3a62362d3dd5dce9  ...                       None
#
#                            attributes.llm.prompt_template.variables  \
# context.span_id
# aa4ba5aef445785c                                               None
# ba042a8a8a032d49                                               None
# 525e9ad3502c1d3f                                               None
# 77528b7ecec4201f                                               None
# 49c542514bec8b37                                               None
# ...                                                             ...
# 25157c04571db771                                               None
# 1b24320f18b047ef  {'context': 'By 100 BC, the city of Rome had e...
# 63bb4656c3e24cdc                                               None
# edaee3b7d922236f                                               None
# 3a62362d3dd5dce9                                               None
#
#                             attributes.llm.prompt_template.template  \
# context.span_id
# aa4ba5aef445785c                                               None
# ba042a8a8a032d49                                               None
# 525e9ad3502c1d3f                                               None
# 77528b7ecec4201f                                               None
# 49c542514bec8b37                                               None
# ...                                                             ...
# 25157c04571db771                                               None
# 1b24320f18b047ef  \n                You are an assistant for que...
# 63bb4656c3e24cdc                                               None
# edaee3b7d922236f                                               None
# 3a62362d3dd5dce9                                               None
#
#                  attributes.llm.token_count.total  \
# context.span_id
# aa4ba5aef445785c                              NaN
# ba042a8a8a032d49                              NaN
# 525e9ad3502c1d3f                              NaN
# 77528b7ecec4201f                              NaN
# 49c542514bec8b37                              NaN
# ...                                           ...
# 25157c04571db771                              NaN
# 1b24320f18b047ef                              NaN
# 63bb4656c3e24cdc                            763.0
# edaee3b7d922236f                              NaN
# 3a62362d3dd5dce9                              NaN
#
#                  attributes.llm.token_count.completion  \
# context.span_id
# aa4ba5aef445785c                                   NaN
# ba042a8a8a032d49                                   NaN
# 525e9ad3502c1d3f                                   NaN
# 77528b7ecec4201f                                   NaN
# 49c542514bec8b37                                   NaN
# ...                                                ...
# 25157c04571db771                                   NaN
# 1b24320f18b047ef                                   NaN
# 63bb4656c3e24cdc                                   4.0
# edaee3b7d922236f                                   NaN
# 3a62362d3dd5dce9                                   NaN
#
#                                      attributes.llm.output_messages  \
# context.span_id
# aa4ba5aef445785c                                               None
# ba042a8a8a032d49                                               None
# 525e9ad3502c1d3f                                               None
# 77528b7ecec4201f                                               None
# 49c542514bec8b37                                               None
# ...                                                             ...
# 25157c04571db771                                               None
# 1b24320f18b047ef                                               None
# 63bb4656c3e24cdc  [{'message.content': 'Julius Caesar', 'message...
# edaee3b7d922236f                                               None
# 3a62362d3dd5dce9                                               None
#
#                                       attributes.llm.input_messages  \
# context.span_id
# aa4ba5aef445785c                                               None
# ba042a8a8a032d49                                               None
# 525e9ad3502c1d3f                                               None
# 77528b7ecec4201f                                               None
# 49c542514bec8b37                                               None
# ...                                                             ...
# 25157c04571db771                                               None
# 1b24320f18b047ef                                               None
# 63bb4656c3e24cdc  [{'message.content': '
#                 You are...
# edaee3b7d922236f                                               None
# 3a62362d3dd5dce9                                               None
#
#                  attributes.llm.model_name attributes.llm.token_count.prompt  \
# context.span_id
# aa4ba5aef445785c                      None                               NaN
# ba042a8a8a032d49                      None                               NaN
# 525e9ad3502c1d3f                      None                               NaN
# 77528b7ecec4201f                      None                               NaN
# 49c542514bec8b37                      None                               NaN
# ...                                    ...                               ...
# 25157c04571db771                      None                               NaN
# 1b24320f18b047ef                      None                               NaN
# 63bb4656c3e24cdc        gpt-3.5-turbo-0125                             759.0
# edaee3b7d922236f                      None                               NaN
# 3a62362d3dd5dce9                      None                               NaN
#
#                                attributes.llm.invocation_parameters
# context.span_id
# aa4ba5aef445785c                                               None
# ba042a8a8a032d49                                               None
# 525e9ad3502c1d3f                                               None
# 77528b7ecec4201f                                               None
# 49c542514bec8b37                                               None
# ...                                                             ...
# 25157c04571db771                                               None
# 1b24320f18b047ef                                               None
# 63bb4656c3e24cdc  {"model": "gpt-3.5-turbo-0125", "model_name": ...
# edaee3b7d922236f                                               None
# 3a62362d3dd5dce9                                               None
#
# [190 rows x 26 columns]

# %%
from phoenix.session.evaluation import get_qa_with_reference, get_retrieved_documents

retrieved_documents_df = get_retrieved_documents(px.active_session())
queries_df = get_qa_with_reference(px.active_session())

# %%
retrieved_documents_df.head()
# Out:
#                                                     context.trace_id  \
# context.span_id  document_position
# aa4ba5aef445785c 0                  40c7ea7560fe000612dbf5375abd2894
#                  1                  40c7ea7560fe000612dbf5375abd2894
#                  2                  40c7ea7560fe000612dbf5375abd2894
# 525e9ad3502c1d3f 0                  34b7e4f25fe292d7c0c4948a7c8be4b2
#                  1                  34b7e4f25fe292d7c0c4948a7c8be4b2
#
#                                                                                 input  \
# context.span_id  document_position
# aa4ba5aef445785c 0                                                       Roman Empire
#                  1                                                       Roman Empire
#                  2                                                       Roman Empire
# 525e9ad3502c1d3f 0                  Who was the second to last emperor of the roma...
#                  1                  Who was the second to last emperor of the roma...
#
#                                                                             reference
# context.span_id  document_position
# aa4ba5aef445785c 0                  The Roman Empire ruled the Mediterranean and m...
#                  1                  The fall of the Western Roman Empire, also cal...
#                  2                  The Holy Roman Empire, also known as the Holy ...
# 525e9ad3502c1d3f 0                  By 476, the position of Western Roman Emperor ...
#                  1                  The first two centuries of the Empire saw a pe...

# %%
queries_df.head()
# Out:
#                                                               input  \
# context.span_id
# aa4ba5aef445785c                                       Roman Empire
# 01ca49ff560fb979  Who was the second to last emperor of the roma...
# e584dbd812dc8913  What year is traditionally considered the foun...
# bd801a8c5cdeab4b                 Who was the first emperor of Rome?
# d29d6c5826f1b1c2  What was the Roman name for the Mediterranean ...
#
#                                                              output  \
# context.span_id
# aa4ba5aef445785c  {"documents": ["page_content='The Roman Empire...
# 01ca49ff560fb979                                 Romulus Augustulus
# e584dbd812dc8913  The founding of Rome is traditionally consider...
# bd801a8c5cdeab4b            Augustus was the first emperor of Rome.
# d29d6c5826f1b1c2  The Roman name for the Mediterranean Sea was "...
#
#                                                           reference
# context.span_id
# aa4ba5aef445785c  The Roman Empire ruled the Mediterranean and m...
# 01ca49ff560fb979  By 476, the position of Western Roman Emperor ...
# e584dbd812dc8913  By 100 BC, the city of Rome had expanded its r...
# bd801a8c5cdeab4b  By 100 BC, the city of Rome had expanded its r...
# d29d6c5826f1b1c2  The Roman Empire ruled the Mediterranean and m...

# %%
from phoenix.evals import OpenAIModel, HallucinationEvaluator, QAEvaluator
from phoenix.evals import run_evals
import nest_asyncio
nest_asyncio.apply()

api_key = os.environ["OPENAI_API_KEY"]
eval_model = OpenAIModel(model="gpt-4-turbo-preview", api_key=api_key)

# Define the evaluators
hallucination_evaluator = HallucinationEvaluator(eval_model)
qa_evaluator = QAEvaluator(eval_model)

hallucination_eval_df, qa_eval_df = run_evals(
    dataframe=queries_df,
    evaluators=[hallucination_evaluator, qa_evaluator],
    provide_explanation=True
)

# Log the evaluations
from phoenix.trace import SpanEvaluations

px.Client().log_evaluations(
    SpanEvaluations(eval_name="Hallucination", dataframe=hallucination_eval_df),
    SpanEvaluations(eval_name="QA Correctness", dataframe=qa_eval_df)
)
# Out:
# I0000 00:00:1737916785.643314 2734713 fork_posix.cc:77] Other threads are currently calling into gRPC, skipping fork() handlers
# run_evals |          | 0/44 (0.0%) | ⏳ 00:00<? | ?it/s
# I0000 00:00:1737916786.008407 2734713 fork_posix.cc:77] Other threads are currently calling into gRPC, skipping fork() handlers

# %%
hallucination_eval_df.head()
# Out:
#                          label  score  \
# context.span_id
# aa4ba5aef445785c       factual      0
# 01ca49ff560fb979  hallucinated      1
# e584dbd812dc8913       factual      0
# bd801a8c5cdeab4b       factual      0
# d29d6c5826f1b1c2  hallucinated      1
#
#                                                         explanation
# context.span_id
# aa4ba5aef445785c  The provided answer is a direct extraction fro...
# 01ca49ff560fb979  The query asks for the identity of the second ...
# e584dbd812dc8913  The reference text explicitly mentions that Ro...
# bd801a8c5cdeab4b  The reference text explicitly states that in 2...
# d29d6c5826f1b1c2  The reference text provided does not mention t...

# %%
qa_eval_df.head()
# Out:
#                       label  score  \
# context.span_id
# aa4ba5aef445785c    correct      1
# 01ca49ff560fb979  incorrect      0
# e584dbd812dc8913    correct      1
# bd801a8c5cdeab4b    correct      1
# d29d6c5826f1b1c2  incorrect      0
#
#                                                         explanation
# context.span_id
# aa4ba5aef445785c  The question provided is "Roman Empire," which...
# 01ca49ff560fb979  The question asks for the identity of the seco...
# e584dbd812dc8913  The reference text explicitly states that Rome...
# bd801a8c5cdeab4b  To determine if the answer is correct, we anal...
# d29d6c5826f1b1c2  The reference text provided does not mention t...

# %%
import pandas as pd
joined_df = pd.merge(hallucination_eval_df, queries_df, on='context.span_id')

joined_df.head()
# Out:
#                          label  score  \
# context.span_id
# aa4ba5aef445785c       factual      0
# 01ca49ff560fb979  hallucinated      1
# e584dbd812dc8913       factual      0
# bd801a8c5cdeab4b       factual      0
# d29d6c5826f1b1c2  hallucinated      1
#
#                                                         explanation  \
# context.span_id
# aa4ba5aef445785c  The provided answer is a direct extraction fro...
# 01ca49ff560fb979  The query asks for the identity of the second ...
# e584dbd812dc8913  The reference text explicitly mentions that Ro...
# bd801a8c5cdeab4b  The reference text explicitly states that in 2...
# d29d6c5826f1b1c2  The reference text provided does not mention t...
#
#                                                               input  \
# context.span_id
# aa4ba5aef445785c                                       Roman Empire
# 01ca49ff560fb979  Who was the second to last emperor of the roma...
# e584dbd812dc8913  What year is traditionally considered the foun...
# bd801a8c5cdeab4b                 Who was the first emperor of Rome?
# d29d6c5826f1b1c2  What was the Roman name for the Mediterranean ...
#
#                                                              output  \
# context.span_id
# aa4ba5aef445785c  {"documents": ["page_content='The Roman Empire...
# 01ca49ff560fb979                                 Romulus Augustulus
# e584dbd812dc8913  The founding of Rome is traditionally consider...
# bd801a8c5cdeab4b            Augustus was the first emperor of Rome.
# d29d6c5826f1b1c2  The Roman name for the Mediterranean Sea was "...
#
#                                                           reference
# context.span_id
# aa4ba5aef445785c  The Roman Empire ruled the Mediterranean and m...
# 01ca49ff560fb979  By 476, the position of Western Roman Emperor ...
# e584dbd812dc8913  By 100 BC, the city of Rome had expanded its r...
# bd801a8c5cdeab4b  By 100 BC, the city of Rome had expanded its r...
# d29d6c5826f1b1c2  The Roman Empire ruled the Mediterranean and m...

# %%
joined_df_2 =  pd.merge(qa_eval_df, queries_df, on='context.span_id')

# %%
joined_df_2.head()
# Out:
#                       label  score  \
# context.span_id
# aa4ba5aef445785c    correct      1
# 01ca49ff560fb979  incorrect      0
# e584dbd812dc8913    correct      1
# bd801a8c5cdeab4b    correct      1
# d29d6c5826f1b1c2  incorrect      0
#
#                                                         explanation  \
# context.span_id
# aa4ba5aef445785c  The question provided is "Roman Empire," which...
# 01ca49ff560fb979  The question asks for the identity of the seco...
# e584dbd812dc8913  The reference text explicitly states that Rome...
# bd801a8c5cdeab4b  To determine if the answer is correct, we anal...
# d29d6c5826f1b1c2  The reference text provided does not mention t...
#
#                                                               input  \
# context.span_id
# aa4ba5aef445785c                                       Roman Empire
# 01ca49ff560fb979  Who was the second to last emperor of the roma...
# e584dbd812dc8913  What year is traditionally considered the foun...
# bd801a8c5cdeab4b                 Who was the first emperor of Rome?
# d29d6c5826f1b1c2  What was the Roman name for the Mediterranean ...
#
#                                                              output  \
# context.span_id
# aa4ba5aef445785c  {"documents": ["page_content='The Roman Empire...
# 01ca49ff560fb979                                 Romulus Augustulus
# e584dbd812dc8913  The founding of Rome is traditionally consider...
# bd801a8c5cdeab4b            Augustus was the first emperor of Rome.
# d29d6c5826f1b1c2  The Roman name for the Mediterranean Sea was "...
#
#                                                           reference
# context.span_id
# aa4ba5aef445785c  The Roman Empire ruled the Mediterranean and m...
# 01ca49ff560fb979  By 476, the position of Western Roman Emperor ...
# e584dbd812dc8913  By 100 BC, the city of Rome had expanded its r...
# bd801a8c5cdeab4b  By 100 BC, the city of Rome had expanded its r...
# d29d6c5826f1b1c2  The Roman Empire ruled the Mediterranean and m...

# %%
correctness_hallucination =  pd.merge(qa_eval_df, hallucination_eval_df, on='context.span_id')

# %%
correctness_hallucination.head()
# Out:
#                     label_x  score_x  \
# context.span_id
# aa4ba5aef445785c    correct        1
# 01ca49ff560fb979  incorrect        0
# e584dbd812dc8913    correct        1
# bd801a8c5cdeab4b    correct        1
# d29d6c5826f1b1c2  incorrect        0
#
#                                                       explanation_x  \
# context.span_id
# aa4ba5aef445785c  The question provided is "Roman Empire," which...
# 01ca49ff560fb979  The question asks for the identity of the seco...
# e584dbd812dc8913  The reference text explicitly states that Rome...
# bd801a8c5cdeab4b  To determine if the answer is correct, we anal...
# d29d6c5826f1b1c2  The reference text provided does not mention t...
#
#                        label_y  score_y  \
# context.span_id
# aa4ba5aef445785c       factual        0
# 01ca49ff560fb979  hallucinated        1
# e584dbd812dc8913       factual        0
# bd801a8c5cdeab4b       factual        0
# d29d6c5826f1b1c2  hallucinated        1
#
#                                                       explanation_y
# context.span_id
# aa4ba5aef445785c  The provided answer is a direct extraction fro...
# 01ca49ff560fb979  The query asks for the identity of the second ...
# e584dbd812dc8913  The reference text explicitly mentions that Ro...
# bd801a8c5cdeab4b  The reference text explicitly states that in 2...
# d29d6c5826f1b1c2  The reference text provided does not mention t...

# %%
correctness_hallucination[(correctness_hallucination['label_y'] == 'factual') & (correctness_hallucination['label_x'] == 'incorrect')]
# Out:
# Empty DataFrame
# Columns: [label_x, score_x, explanation_x, label_y, score_y, explanation_y]
# Index: []

# %% [markdown]
# - why don't correctness and hallucination dfs come with input, output?

# %%
from phoenix.evals import (
    RAG_RELEVANCY_PROMPT_RAILS_MAP,
    RAG_RELEVANCY_PROMPT_TEMPLATE,
    OpenAIModel,
    llm_classify,
)

retrieved_documents_eval = llm_classify(
    dataframe=retrieved_documents_df,
    model=OpenAIModel(model="gpt-4o", temperature=0.0),
    template=RAG_RELEVANCY_PROMPT_TEMPLATE,
    rails=list(RAG_RELEVANCY_PROMPT_RAILS_MAP.values()),
    provide_explanation=True,
)

retrieved_documents_eval["score"] = (
    retrieved_documents_eval.label[~retrieved_documents_eval.label.isna()] == "relevant"
).astype(int)
# Out:
# llm_classify |          | 0/87 (0.0%) | ⏳ 00:00<? | ?it/s

# %%
retrieved_documents_eval.head()
# Out:
#                                         label  \
# context.span_id  document_position
# aa4ba5aef445785c 0                   relevant
#                  1                   relevant
#                  2                  unrelated
# 525e9ad3502c1d3f 0                  unrelated
#                  1                  unrelated
#
#                                                                           explanation  \
# context.span_id  document_position
# aa4ba5aef445785c 0                  The question is about the 'Roman Empire,' whic...
#                  1                  The question is simply 'Roman Empire,' which i...
#                  2                  The question is about the 'Roman Empire,' whic...
# 525e9ad3502c1d3f 0                  The question asks for the identity of the seco...
#                  1                  To determine if the reference text is relevant...
#
#                                    exceptions execution_status  \
# context.span_id  document_position
# aa4ba5aef445785c 0                         []        COMPLETED
#                  1                         []        COMPLETED
#                  2                         []        COMPLETED
# 525e9ad3502c1d3f 0                         []        COMPLETED
#                  1                         []        COMPLETED
#
#                                     execution_seconds  score
# context.span_id  document_position
# aa4ba5aef445785c 0                           2.381172      1
#                  1                           3.717477      1
#                  2                           4.857805      0
# 525e9ad3502c1d3f 0                           2.690012      0
#                  1                           3.867020      0

# %%
from phoenix.trace import DocumentEvaluations

px.Client().log_evaluations(
    DocumentEvaluations(eval_name="Relevance", dataframe=retrieved_documents_eval)
)

# %%
queries_df.head()
# Out:
#                                                               input  \
# context.span_id
# aa4ba5aef445785c                                       Roman Empire
# 01ca49ff560fb979  Who was the second to last emperor of the roma...
# e584dbd812dc8913  What year is traditionally considered the foun...
# bd801a8c5cdeab4b                 Who was the first emperor of Rome?
# d29d6c5826f1b1c2  What was the Roman name for the Mediterranean ...
#
#                                                              output  \
# context.span_id
# aa4ba5aef445785c  {"documents": ["page_content='The Roman Empire...
# 01ca49ff560fb979                                 Romulus Augustulus
# e584dbd812dc8913  The founding of Rome is traditionally consider...
# bd801a8c5cdeab4b            Augustus was the first emperor of Rome.
# d29d6c5826f1b1c2  The Roman name for the Mediterranean Sea was "...
#
#                                                           reference
# context.span_id
# aa4ba5aef445785c  The Roman Empire ruled the Mediterranean and m...
# 01ca49ff560fb979  By 476, the position of Western Roman Emperor ...
# e584dbd812dc8913  By 100 BC, the city of Rome had expanded its r...
# bd801a8c5cdeab4b  By 100 BC, the city of Rome had expanded its r...
# d29d6c5826f1b1c2  The Roman Empire ruled the Mediterranean and m...

# %%
from openai import OpenAI
client = OpenAI()

def get_embedding(text, model="text-embedding-3-small"):
   text = text.replace("\n", " ")
   return client.embeddings.create(input = [text], model=model).data[0].embedding

queries_df['ada_embedding'] = queries_df["input"].apply(get_embedding)
queries_df.head()
# Out:
#                                                               input  \
# context.span_id
# aa4ba5aef445785c                                       Roman Empire
# 01ca49ff560fb979  Who was the second to last emperor of the roma...
# e584dbd812dc8913  What year is traditionally considered the foun...
# bd801a8c5cdeab4b                 Who was the first emperor of Rome?
# d29d6c5826f1b1c2  What was the Roman name for the Mediterranean ...
#
#                                                              output  \
# context.span_id
# aa4ba5aef445785c  {"documents": ["page_content='The Roman Empire...
# 01ca49ff560fb979                                 Romulus Augustulus
# e584dbd812dc8913  The founding of Rome is traditionally consider...
# bd801a8c5cdeab4b            Augustus was the first emperor of Rome.
# d29d6c5826f1b1c2  The Roman name for the Mediterranean Sea was "...
#
#                                                           reference  \
# context.span_id
# aa4ba5aef445785c  The Roman Empire ruled the Mediterranean and m...
# 01ca49ff560fb979  By 476, the position of Western Roman Emperor ...
# e584dbd812dc8913  By 100 BC, the city of Rome had expanded its r...
# bd801a8c5cdeab4b  By 100 BC, the city of Rome had expanded its r...
# d29d6c5826f1b1c2  The Roman Empire ruled the Mediterranean and m...
#
#                                                       ada_embedding
# context.span_id
# aa4ba5aef445785c  [-0.049663741141557693, 0.01780897006392479, 0...
# 01ca49ff560fb979  [0.0034670475870370865, 0.018989551812410355, ...
# e584dbd812dc8913  [0.02312874048948288, -0.0018601700430735946, ...
# bd801a8c5cdeab4b  [0.012941939756274223, -0.03062393143773079, -...
# d29d6c5826f1b1c2  [0.000884795212186873, 0.019955161958932877, 0...

# %% [markdown]
# # evaluation

# %%
os.environ["PHOENIX_COLLECTOR_ENDPOINT"] = "http://localhost:6006"

# %% [markdown]
# # experiments - NBA toy dataset

# %%
# import phoenix as px
# import openai
# from textwrap import dedent

# # Create a list of dictionaries with examples
# inputs = [{"question": "Which team won the most games?"}, {"question": "Which team won the most games in 2015?"}, {"question": "Who led the league in 3 point shots?"}]
# outputs = [{"answer": "Team A"}, {"answer": "Team B"}, {"answer": "Player X"}]

# # Upload the dataset to Phoenix
# client = px.Client()
# dataset = client.upload_dataset(
#     inputs=inputs,
#     outputs=outputs,
#     dataset_name="nba-questions-v4"
# )

# openai.api_key = os.environ["OPENAI_API_KEY"]

# # Define the text2sql function using the new API interface
# def text2sql(question):
#     try:
#         response = openai.chat.completions.create(
#             model="gpt-3.5-turbo",
#             messages=[
#                 {"role": "system", "content": dedent("""
#                     You are a SQL expert, and you are given a table named nba_players with the following columns: player_name, three_point_shots. 
#                     Another table named nba_teams with columns: team_name, season, wins. 
#                     Write a SQL query corresponding to the user's request. Return just the query text, with no formatting (backticks, markdown, etc.).
#                 """)},
#                 {"role": "user", "content": question}
#             ]
#         )
#         query = response.choices[0].message.content.strip()
#         return {"results": query, "error": None}
#     except Exception as e:
#         return {"results": None, "error": str(e)}

# def task(x):
#     return text2sql(x["question"])

# def no_error(output) -> bool:
#     return output.get("error") is None

# def has_results(output) -> bool:
#     return bool(output.get("results"))

# from phoenix.trace.openai import OpenAIInstrumentor

# OpenAIInstrumentor().instrument()

# from phoenix.experiments import run_experiment

# run_experiment(dataset, task=task, evaluators=[no_error, has_results])

# %% [markdown]
# # experiment on Roman Empire RAG

# %%
import numpy as np
import phoenix as px
import openai
from textwrap import dedent

# dataset
client = px.Client(endpoint="http://localhost:6006")
dataset = client.get_dataset(id="RGF0YXNldDox")

openai.api_key = os.environ["OPENAI_API_KEY"]

# define task
def ask_chat(question):
    try:
        response = openai.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": dedent("""
                    You are an expert on Roman History. If you don't know the answer, just say you don't know.
                """)},
                {"role": "user", "content": question}
            ]
        )
        query = response.choices[0].message.content.strip()
        return {"results": query, "error": None}
    except Exception as e:
        return {"results": None, "error": str(e)}
    
def task(x):
    return ask_chat(x["input"])

# define evaluators
def no_error(output) -> bool:
    return output.get("error") is None

def has_results(output) -> bool:
    return output.get("results") is not None

def correctness(output, expected) -> bool:
    result = output.get("results")
    expected_output = expected.get("output")
    
    # Get embeddings for result and expected_output
    result_embedding_response = openai.embeddings.create(input=result, model="text-embedding-ada-002")
    expected_embedding_response = openai.embeddings.create(input=expected_output, model="text-embedding-ada-002")

    # Extract embeddings from the responses
    result_embedding = result_embedding_response.data[0].embedding
    expected_embedding = expected_embedding_response.data[0].embedding

    # Calculate cosine similarity
    similarity = np.dot(result_embedding, expected_embedding) / (np.linalg.norm(result_embedding) * np.linalg.norm(expected_embedding))
    
    # Define a threshold for semantic similarity
    threshold = 0.90
    return similarity >= threshold


from phoenix.trace.openai import OpenAIInstrumentor

OpenAIInstrumentor().instrument()

from phoenix.experiments import run_experiment

experiment = run_experiment(dataset, task=task, evaluators=[no_error, has_results, correctness])
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# Cell In[28], line 8
#       6 # dataset
#       7 client = px.Client(endpoint="http://localhost:6006")
# ----> 8 dataset = client.get_dataset(id="RGF0YXNldDox")
#      10 openai.api_key = os.environ["OPENAI_API_KEY"]
#      12 # define task
#
# File /opt/homebrew/lib/python3.11/site-packages/phoenix/session/client.py:372, in Client.get_dataset(self, id, name, version_id)
#     366     raise ValueError("Dataset id or name must be provided.")
#     368 response = self._client.get(
#     369     urljoin(self._base_url, f"v1/datasets/{quote(id)}/examples"),
#     370     params={"version_id": version_id} if version_id else None,
#     371 )
# --> 372 response.raise_for_status()
#     373 data = response.json()["data"]
#     374 examples = {
#     375     example["id"]: Example(
#     376         id=example["id"],
#    (...)
#     382     for example in data["examples"]
#     383 }
#
# File /opt/homebrew/lib/python3.11/site-packages/httpx/_models.py:761, in Response.raise_for_status(self)
#     759 error_type = error_types.get(status_class, "Invalid status code")
#     760 message = message.format(self, error_type=error_type)
# --> 761 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '404 Not Found' for url 'http://localhost:6006/v1/datasets/RGF0YXNldDox/examples'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/404

# %%
evaluations = experiment.get_evaluations()
print(evaluations)
# Out:
#                                  name  score label  \
# run_id
# RXhwZXJpbWVudFJ1bjox         no_error    1.0  True
# RXhwZXJpbWVudFJ1bjox      has_results    1.0  True
# RXhwZXJpbWVudFJ1bjox      correctness    1.0  None
# RXhwZXJpbWVudFJ1bjoy         no_error    1.0  True
# RXhwZXJpbWVudFJ1bjoy      has_results    1.0  True
# RXhwZXJpbWVudFJ1bjoy      correctness    1.0  None
# RXhwZXJpbWVudFJ1bjoz         no_error    1.0  True
# RXhwZXJpbWVudFJ1bjoz      has_results    1.0  True
# RXhwZXJpbWVudFJ1bjoz      correctness    0.0  None
# RXhwZXJpbWVudFJ1bjo0         no_error    1.0  True
# RXhwZXJpbWVudFJ1bjo0      has_results    1.0  True
# RXhwZXJpbWVudFJ1bjo0      correctness    1.0  None
# RXhwZXJpbWVudFJ1bjo1         no_error    1.0  True
# RXhwZXJpbWVudFJ1bjo1      has_results    1.0  True
# RXhwZXJpbWVudFJ1bjo1      correctness    1.0  None
# RXhwZXJpbWVudFJ1bjo2         no_error    1.0  True
# RXhwZXJpbWVudFJ1bjo2      has_results    1.0  True
# RXhwZXJpbWVudFJ1bjo2      correctness    1.0  None
# RXhwZXJpbWVudFJ1bjo3         no_error    1.0  True
# RXhwZXJpbWVudFJ1bjo3      has_results    1.0  True
# RXhwZXJpbWVudFJ1bjo3      correctness    1.0  None
# RXhwZXJpbWVudFJ1bjo4         no_error    1.0  True
# RXhwZXJpbWVudFJ1bjo4      has_results    1.0  True
# RXhwZXJpbWVudFJ1bjo4      correctness    0.0  None
# RXhwZXJpbWVudFJ1bjo5         no_error    1.0  True
# RXhwZXJpbWVudFJ1bjo5      has_results    1.0  True
# RXhwZXJpbWVudFJ1bjo5      correctness    1.0  None
# RXhwZXJpbWVudFJ1bjoxMA==     no_error    1.0  True
# RXhwZXJpbWVudFJ1bjoxMA==  has_results    1.0  True
# RXhwZXJpbWVudFJ1bjoxMA==  correctness    1.0  None
# RXhwZXJpbWVudFJ1bjoxMQ==     no_error    1.0  True
# RXhwZXJpbWVudFJ1bjoxMQ==  has_results    1.0  True
# RXhwZXJpbWVudFJ1bjoxMQ==  correctness    0.0  None
# RXhwZXJpbWVudFJ1bjoxMg==     no_error    1.0  True
# RXhwZXJpbWVudFJ1bjoxMg==  has_results    1.0  True
# RXhwZXJpbWVudFJ1bjoxMg==  correctness    0.0  None
# RXhwZXJpbWVudFJ1bjoxMw==     no_error    1.0  True
# RXhwZXJpbWVudFJ1bjoxMw==  has_results    1.0  True
# RXhwZXJpbWVudFJ1bjoxMw==  correctness    1.0  None
# RXhwZXJpbWVudFJ1bjoxNA==     no_error    1.0  True
# RXhwZXJpbWVudFJ1bjoxNA==  has_results    1.0  True
# RXhwZXJpbWVudFJ1bjoxNA==  correctness    1.0  None
# RXhwZXJpbWVudFJ1bjoxNQ==     no_error    1.0  True
# RXhwZXJpbWVudFJ1bjoxNQ==  has_results    1.0  True
# RXhwZXJpbWVudFJ1bjoxNQ==  correctness    1.0  None
# RXhwZXJpbWVudFJ1bjoxNg==     no_error    1.0  True
# RXhwZXJpbWVudFJ1bjoxNg==  has_results    1.0  True
# RXhwZXJpbWVudFJ1bjoxNg==  correctness    1.0  None
#
#                                                                      output  \
# run_id
# RXhwZXJpbWVudFJ1bjox      {'results': 'The second to last emperor of the...
# RXhwZXJpbWVudFJ1bjox      {'results': 'The second to last emperor of the...
# RXhwZXJpbWVudFJ1bjox      {'results': 'The second to last emperor of the...
# RXhwZXJpbWVudFJ1bjoy      {'results': 'The Roman name for the Mediterran...
# RXhwZXJpbWVudFJ1bjoy      {'results': 'The Roman name for the Mediterran...
# RXhwZXJpbWVudFJ1bjoy      {'results': 'The Roman name for the Mediterran...
# RXhwZXJpbWVudFJ1bjoz      {'results': 'The Roman general who famously cr...
# RXhwZXJpbWVudFJ1bjoz      {'results': 'The Roman general who famously cr...
# RXhwZXJpbWVudFJ1bjoz      {'results': 'The Roman general who famously cr...
# RXhwZXJpbWVudFJ1bjo0      {'results': 'The Romans used amphitheaters for...
# RXhwZXJpbWVudFJ1bjo0      {'results': 'The Romans used amphitheaters for...
# RXhwZXJpbWVudFJ1bjo0      {'results': 'The Romans used amphitheaters for...
# RXhwZXJpbWVudFJ1bjo1      {'results': 'The Roman emperor who initiated t...
# RXhwZXJpbWVudFJ1bjo1      {'results': 'The Roman emperor who initiated t...
# RXhwZXJpbWVudFJ1bjo1      {'results': 'The Roman emperor who initiated t...
# RXhwZXJpbWVudFJ1bjo2      {'results': 'In Roman mythology, the god of wa...
# RXhwZXJpbWVudFJ1bjo2      {'results': 'In Roman mythology, the god of wa...
# RXhwZXJpbWVudFJ1bjo2      {'results': 'In Roman mythology, the god of wa...
# RXhwZXJpbWVudFJ1bjo3      {'results': 'The advisory council of aristocra...
# RXhwZXJpbWVudFJ1bjo3      {'results': 'The advisory council of aristocra...
# RXhwZXJpbWVudFJ1bjo3      {'results': 'The advisory council of aristocra...
# RXhwZXJpbWVudFJ1bjo4      {'results': 'The Roman term for a large estate...
# RXhwZXJpbWVudFJ1bjo4      {'results': 'The Roman term for a large estate...
# RXhwZXJpbWVudFJ1bjo4      {'results': 'The Roman term for a large estate...
# RXhwZXJpbWVudFJ1bjo5      {'results': 'The Roman structure completed in ...
# RXhwZXJpbWVudFJ1bjo5      {'results': 'The Roman structure completed in ...
# RXhwZXJpbWVudFJ1bjo5      {'results': 'The Roman structure completed in ...
# RXhwZXJpbWVudFJ1bjoxMA==  {'results': 'The primary purpose of the Roman ...
# RXhwZXJpbWVudFJ1bjoxMA==  {'results': 'The primary purpose of the Roman ...
# RXhwZXJpbWVudFJ1bjoxMA==  {'results': 'The primary purpose of the Roman ...
# RXhwZXJpbWVudFJ1bjoxMQ==  {'results': 'The Roman poet known for writing ...
# RXhwZXJpbWVudFJ1bjoxMQ==  {'results': 'The Roman poet known for writing ...
# RXhwZXJpbWVudFJ1bjoxMQ==  {'results': 'The Roman poet known for writing ...
# RXhwZXJpbWVudFJ1bjoxMg==  {'results': 'The Roman emperor famous for buil...
# RXhwZXJpbWVudFJ1bjoxMg==  {'results': 'The Roman emperor famous for buil...
# RXhwZXJpbWVudFJ1bjoxMg==  {'results': 'The Roman emperor famous for buil...
# RXhwZXJpbWVudFJ1bjoxMw==  {'results': 'The Roman currency was called the...
# RXhwZXJpbWVudFJ1bjoxMw==  {'results': 'The Roman currency was called the...
# RXhwZXJpbWVudFJ1bjoxMw==  {'results': 'The Roman currency was called the...
# RXhwZXJpbWVudFJ1bjoxNA==  {'results': 'The type of Roman building used f...
# RXhwZXJpbWVudFJ1bjoxNA==  {'results': 'The type of Roman building used f...
# RXhwZXJpbWVudFJ1bjoxNA==  {'results': 'The type of Roman building used f...
# RXhwZXJpbWVudFJ1bjoxNQ==  {'results': 'The Roman goddess of wisdom and w...
# RXhwZXJpbWVudFJ1bjoxNQ==  {'results': 'The Roman goddess of wisdom and w...
# RXhwZXJpbWVudFJ1bjoxNQ==  {'results': 'The Roman goddess of wisdom and w...
# RXhwZXJpbWVudFJ1bjoxNg==  {'results': 'The Roman general known for his c...
# RXhwZXJpbWVudFJ1bjoxNg==  {'results': 'The Roman general known for his c...
# RXhwZXJpbWVudFJ1bjoxNg==  {'results': 'The Roman general known for his c...
#
#                                                                       input  \
# run_id
# RXhwZXJpbWVudFJ1bjox      {'input': 'Who was the second to last emperor ...
# RXhwZXJpbWVudFJ1bjox      {'input': 'Who was the second to last emperor ...
# RXhwZXJpbWVudFJ1bjox      {'input': 'Who was the second to last emperor ...
# RXhwZXJpbWVudFJ1bjoy      {'input': 'What was the Roman name for the Med...
# RXhwZXJpbWVudFJ1bjoy      {'input': 'What was the Roman name for the Med...
# RXhwZXJpbWVudFJ1bjoy      {'input': 'What was the Roman name for the Med...
# RXhwZXJpbWVudFJ1bjoz      {'input': 'Which Roman general famously crosse...
# RXhwZXJpbWVudFJ1bjoz      {'input': 'Which Roman general famously crosse...
# RXhwZXJpbWVudFJ1bjoz      {'input': 'Which Roman general famously crosse...
# RXhwZXJpbWVudFJ1bjo0      {'input': 'What structure was used by Romans f...
# RXhwZXJpbWVudFJ1bjo0      {'input': 'What structure was used by Romans f...
# RXhwZXJpbWVudFJ1bjo0      {'input': 'What structure was used by Romans f...
# RXhwZXJpbWVudFJ1bjo1      {'input': 'Which Roman emperor initiated the p...
# RXhwZXJpbWVudFJ1bjo1      {'input': 'Which Roman emperor initiated the p...
# RXhwZXJpbWVudFJ1bjo1      {'input': 'Which Roman emperor initiated the p...
# RXhwZXJpbWVudFJ1bjo2      {'input': 'In Roman mythology, who was the god...
# RXhwZXJpbWVudFJ1bjo2      {'input': 'In Roman mythology, who was the god...
# RXhwZXJpbWVudFJ1bjo2      {'input': 'In Roman mythology, who was the god...
# RXhwZXJpbWVudFJ1bjo3      {'input': 'What was the name of the Roman Sena...
# RXhwZXJpbWVudFJ1bjo3      {'input': 'What was the name of the Roman Sena...
# RXhwZXJpbWVudFJ1bjo3      {'input': 'What was the name of the Roman Sena...
# RXhwZXJpbWVudFJ1bjo4      {'input': 'What was the Roman term for a large...
# RXhwZXJpbWVudFJ1bjo4      {'input': 'What was the Roman term for a large...
# RXhwZXJpbWVudFJ1bjo4      {'input': 'What was the Roman term for a large...
# RXhwZXJpbWVudFJ1bjo5      {'input': 'Which Roman structure, completed in...
# RXhwZXJpbWVudFJ1bjo5      {'input': 'Which Roman structure, completed in...
# RXhwZXJpbWVudFJ1bjo5      {'input': 'Which Roman structure, completed in...
# RXhwZXJpbWVudFJ1bjoxMA==  {'input': 'What was the primary purpose of the...
# RXhwZXJpbWVudFJ1bjoxMA==  {'input': 'What was the primary purpose of the...
# RXhwZXJpbWVudFJ1bjoxMA==  {'input': 'What was the primary purpose of the...
# RXhwZXJpbWVudFJ1bjoxMQ==  {'input': 'Who was the Roman poet known for wr...
# RXhwZXJpbWVudFJ1bjoxMQ==  {'input': 'Who was the Roman poet known for wr...
# RXhwZXJpbWVudFJ1bjoxMQ==  {'input': 'Who was the Roman poet known for wr...
# RXhwZXJpbWVudFJ1bjoxMg==  {'input': 'Which Roman emperor is famous for b...
# RXhwZXJpbWVudFJ1bjoxMg==  {'input': 'Which Roman emperor is famous for b...
# RXhwZXJpbWVudFJ1bjoxMg==  {'input': 'Which Roman emperor is famous for b...
# RXhwZXJpbWVudFJ1bjoxMw==   {'input': 'What was the Roman currency called?'}
# RXhwZXJpbWVudFJ1bjoxMw==   {'input': 'What was the Roman currency called?'}
# RXhwZXJpbWVudFJ1bjoxMw==   {'input': 'What was the Roman currency called?'}
# RXhwZXJpbWVudFJ1bjoxNA==  {'input': 'What type of Roman building was use...
# RXhwZXJpbWVudFJ1bjoxNA==  {'input': 'What type of Roman building was use...
# RXhwZXJpbWVudFJ1bjoxNA==  {'input': 'What type of Roman building was use...
# RXhwZXJpbWVudFJ1bjoxNQ==  {'input': 'Who was the Roman goddess of wisdom...
# RXhwZXJpbWVudFJ1bjoxNQ==  {'input': 'Who was the Roman goddess of wisdom...
# RXhwZXJpbWVudFJ1bjoxNQ==  {'input': 'Who was the Roman goddess of wisdom...
# RXhwZXJpbWVudFJ1bjoxNg==  {'input': 'Which Roman general was known for h...
# RXhwZXJpbWVudFJ1bjoxNg==  {'input': 'Which Roman general was known for h...
# RXhwZXJpbWVudFJ1bjoxNg==  {'input': 'Which Roman general was known for h...
#
#                                                                    expected  \
# run_id
# RXhwZXJpbWVudFJ1bjox      {'output': 'The second to last emperor of the ...
# RXhwZXJpbWVudFJ1bjox      {'output': 'The second to last emperor of the ...
# RXhwZXJpbWVudFJ1bjox      {'output': 'The second to last emperor of the ...
# RXhwZXJpbWVudFJ1bjoy      {'output': 'The Roman name for the Mediterrane...
# RXhwZXJpbWVudFJ1bjoy      {'output': 'The Roman name for the Mediterrane...
# RXhwZXJpbWVudFJ1bjoy      {'output': 'The Roman name for the Mediterrane...
# RXhwZXJpbWVudFJ1bjoz                            {'output': 'Julius Caesar'}
# RXhwZXJpbWVudFJ1bjoz                            {'output': 'Julius Caesar'}
# RXhwZXJpbWVudFJ1bjoz                            {'output': 'Julius Caesar'}
# RXhwZXJpbWVudFJ1bjo0      {'output': 'The Romans used amphitheaters for ...
# RXhwZXJpbWVudFJ1bjo0      {'output': 'The Romans used amphitheaters for ...
# RXhwZXJpbWVudFJ1bjo0      {'output': 'The Romans used amphitheaters for ...
# RXhwZXJpbWVudFJ1bjo1      {'output': 'The Roman emperor who initiated th...
# RXhwZXJpbWVudFJ1bjo1      {'output': 'The Roman emperor who initiated th...
# RXhwZXJpbWVudFJ1bjo1      {'output': 'The Roman emperor who initiated th...
# RXhwZXJpbWVudFJ1bjo2      {'output': 'Mars was the god of war in Roman m...
# RXhwZXJpbWVudFJ1bjo2      {'output': 'Mars was the god of war in Roman m...
# RXhwZXJpbWVudFJ1bjo2      {'output': 'Mars was the god of war in Roman m...
# RXhwZXJpbWVudFJ1bjo3      {'output': 'The name of the Roman Senate's adv...
# RXhwZXJpbWVudFJ1bjo3      {'output': 'The name of the Roman Senate's adv...
# RXhwZXJpbWVudFJ1bjo3      {'output': 'The name of the Roman Senate's adv...
# RXhwZXJpbWVudFJ1bjo4                              {'output': 'Latifundium'}
# RXhwZXJpbWVudFJ1bjo4                              {'output': 'Latifundium'}
# RXhwZXJpbWVudFJ1bjo4                              {'output': 'Latifundium'}
# RXhwZXJpbWVudFJ1bjo5      {'output': 'The Roman structure completed in 8...
# RXhwZXJpbWVudFJ1bjo5      {'output': 'The Roman structure completed in 8...
# RXhwZXJpbWVudFJ1bjo5      {'output': 'The Roman structure completed in 8...
# RXhwZXJpbWVudFJ1bjoxMA==  {'output': 'The primary purpose of the Roman a...
# RXhwZXJpbWVudFJ1bjoxMA==  {'output': 'The primary purpose of the Roman a...
# RXhwZXJpbWVudFJ1bjoxMA==  {'output': 'The primary purpose of the Roman a...
# RXhwZXJpbWVudFJ1bjoxMQ==                               {'output': 'Virgil'}
# RXhwZXJpbWVudFJ1bjoxMQ==                               {'output': 'Virgil'}
# RXhwZXJpbWVudFJ1bjoxMQ==                               {'output': 'Virgil'}
# RXhwZXJpbWVudFJ1bjoxMg==                              {'output': 'Hadrian'}
# RXhwZXJpbWVudFJ1bjoxMg==                              {'output': 'Hadrian'}
# RXhwZXJpbWVudFJ1bjoxMg==                              {'output': 'Hadrian'}
# RXhwZXJpbWVudFJ1bjoxMw==  {'output': 'The Roman currency was called the ...
# RXhwZXJpbWVudFJ1bjoxMw==  {'output': 'The Roman currency was called the ...
# RXhwZXJpbWVudFJ1bjoxMw==  {'output': 'The Roman currency was called the ...
# RXhwZXJpbWVudFJ1bjoxNA==  {'output': 'Roman building used for public bat...
# RXhwZXJpbWVudFJ1bjoxNA==  {'output': 'Roman building used for public bat...
# RXhwZXJpbWVudFJ1bjoxNA==  {'output': 'Roman building used for public bat...
# RXhwZXJpbWVudFJ1bjoxNQ==  {'output': 'The Roman goddess of wisdom and wa...
# RXhwZXJpbWVudFJ1bjoxNQ==  {'output': 'The Roman goddess of wisdom and wa...
# RXhwZXJpbWVudFJ1bjoxNQ==  {'output': 'The Roman goddess of wisdom and wa...
# RXhwZXJpbWVudFJ1bjoxNg==  {'output': 'Julius Caesar was the Roman genera...
# RXhwZXJpbWVudFJ1bjoxNg==  {'output': 'Julius Caesar was the Roman genera...
# RXhwZXJpbWVudFJ1bjoxNg==  {'output': 'Julius Caesar was the Roman genera...
#
#                                                                    metadata  \
# run_id
# RXhwZXJpbWVudFJ1bjox      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjox      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjox      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoy      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoy      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoy      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoz      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoz      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoz      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjo0      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjo0      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjo0      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjo1      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjo1      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjo1      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjo2      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjo2      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjo2      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjo3      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjo3      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjo3      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjo4      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjo4      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjo4      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjo5      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjo5      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjo5      {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoxMA==  {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoxMA==  {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoxMA==  {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoxMQ==  {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoxMQ==  {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoxMQ==  {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoxMg==  {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoxMg==  {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoxMg==  {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoxMw==  {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoxMw==  {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoxMw==  {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoxNA==  {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoxNA==  {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoxNA==  {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoxNQ==  {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoxNQ==  {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoxNQ==  {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoxNg==  {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoxNg==  {'openinference': {'span': {'kind': 'CHAIN'}},...
# RXhwZXJpbWVudFJ1bjoxNg==  {'openinference': {'span': {'kind': 'CHAIN'}},...
#
#                                         example_id
# run_id
# RXhwZXJpbWVudFJ1bjox      RGF0YXNldEV4YW1wbGU6MQ==
# RXhwZXJpbWVudFJ1bjox      RGF0YXNldEV4YW1wbGU6MQ==
# RXhwZXJpbWVudFJ1bjox      RGF0YXNldEV4YW1wbGU6MQ==
# RXhwZXJpbWVudFJ1bjoy      RGF0YXNldEV4YW1wbGU6Mg==
# RXhwZXJpbWVudFJ1bjoy      RGF0YXNldEV4YW1wbGU6Mg==
# RXhwZXJpbWVudFJ1bjoy      RGF0YXNldEV4YW1wbGU6Mg==
# RXhwZXJpbWVudFJ1bjoz      RGF0YXNldEV4YW1wbGU6Mw==
# RXhwZXJpbWVudFJ1bjoz      RGF0YXNldEV4YW1wbGU6Mw==
# RXhwZXJpbWVudFJ1bjoz      RGF0YXNldEV4YW1wbGU6Mw==
# RXhwZXJpbWVudFJ1bjo0      RGF0YXNldEV4YW1wbGU6NA==
# RXhwZXJpbWVudFJ1bjo0      RGF0YXNldEV4YW1wbGU6NA==
# RXhwZXJpbWVudFJ1bjo0      RGF0YXNldEV4YW1wbGU6NA==
# RXhwZXJpbWVudFJ1bjo1      RGF0YXNldEV4YW1wbGU6NQ==
# RXhwZXJpbWVudFJ1bjo1      RGF0YXNldEV4YW1wbGU6NQ==
# RXhwZXJpbWVudFJ1bjo1      RGF0YXNldEV4YW1wbGU6NQ==
# RXhwZXJpbWVudFJ1bjo2      RGF0YXNldEV4YW1wbGU6Ng==
# RXhwZXJpbWVudFJ1bjo2      RGF0YXNldEV4YW1wbGU6Ng==
# RXhwZXJpbWVudFJ1bjo2      RGF0YXNldEV4YW1wbGU6Ng==
# RXhwZXJpbWVudFJ1bjo3      RGF0YXNldEV4YW1wbGU6Nw==
# RXhwZXJpbWVudFJ1bjo3      RGF0YXNldEV4YW1wbGU6Nw==
# RXhwZXJpbWVudFJ1bjo3      RGF0YXNldEV4YW1wbGU6Nw==
# RXhwZXJpbWVudFJ1bjo4      RGF0YXNldEV4YW1wbGU6OA==
# RXhwZXJpbWVudFJ1bjo4      RGF0YXNldEV4YW1wbGU6OA==
# RXhwZXJpbWVudFJ1bjo4      RGF0YXNldEV4YW1wbGU6OA==
# RXhwZXJpbWVudFJ1bjo5      RGF0YXNldEV4YW1wbGU6OQ==
# RXhwZXJpbWVudFJ1bjo5      RGF0YXNldEV4YW1wbGU6OQ==
# RXhwZXJpbWVudFJ1bjo5      RGF0YXNldEV4YW1wbGU6OQ==
# RXhwZXJpbWVudFJ1bjoxMA==  RGF0YXNldEV4YW1wbGU6MTA=
# RXhwZXJpbWVudFJ1bjoxMA==  RGF0YXNldEV4YW1wbGU6MTA=
# RXhwZXJpbWVudFJ1bjoxMA==  RGF0YXNldEV4YW1wbGU6MTA=
# RXhwZXJpbWVudFJ1bjoxMQ==  RGF0YXNldEV4YW1wbGU6MTE=
# RXhwZXJpbWVudFJ1bjoxMQ==  RGF0YXNldEV4YW1wbGU6MTE=
# RXhwZXJpbWVudFJ1bjoxMQ==  RGF0YXNldEV4YW1wbGU6MTE=
# RXhwZXJpbWVudFJ1bjoxMg==  RGF0YXNldEV4YW1wbGU6MTI=
# RXhwZXJpbWVudFJ1bjoxMg==  RGF0YXNldEV4YW1wbGU6MTI=
# RXhwZXJpbWVudFJ1bjoxMg==  RGF0YXNldEV4YW1wbGU6MTI=
# RXhwZXJpbWVudFJ1bjoxMw==  RGF0YXNldEV4YW1wbGU6MTM=
# RXhwZXJpbWVudFJ1bjoxMw==  RGF0YXNldEV4YW1wbGU6MTM=
# RXhwZXJpbWVudFJ1bjoxMw==  RGF0YXNldEV4YW1wbGU6MTM=
# RXhwZXJpbWVudFJ1bjoxNA==  RGF0YXNldEV4YW1wbGU6MTQ=
# RXhwZXJpbWVudFJ1bjoxNA==  RGF0YXNldEV4YW1wbGU6MTQ=
# RXhwZXJpbWVudFJ1bjoxNA==  RGF0YXNldEV4YW1wbGU6MTQ=
# RXhwZXJpbWVudFJ1bjoxNQ==  RGF0YXNldEV4YW1wbGU6MTU=
# RXhwZXJpbWVudFJ1bjoxNQ==  RGF0YXNldEV4YW1wbGU6MTU=
# RXhwZXJpbWVudFJ1bjoxNQ==  RGF0YXNldEV4YW1wbGU6MTU=
# RXhwZXJpbWVudFJ1bjoxNg==  RGF0YXNldEV4YW1wbGU6MTY=
# RXhwZXJpbWVudFJ1bjoxNg==  RGF0YXNldEV4YW1wbGU6MTY=
# RXhwZXJpbWVudFJ1bjoxNg==  RGF0YXNldEV4YW1wbGU6MTY=
